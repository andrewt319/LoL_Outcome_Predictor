# %% [markdown]
# League of Legends Model Building
#
# **Name(s)**: Andrew Tan
#
# **Website Link**: (your website link)

# %% [markdown]
# ## Code

# %%
import pandas as pd
import numpy as np
import os

import plotly.express as px
pd.options.plotting.backend = 'plotly'

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
league = pd.read_csv(os.path.join('data', '2022_LoL_dataset.csv'), low_memory=False)
league
# Out:
#                        gameid datacompleteness  \
# 0       ESPORTSTMNT01_2690210         complete
# 1       ESPORTSTMNT01_2690210         complete
# 2       ESPORTSTMNT01_2690210         complete
# 3       ESPORTSTMNT01_2690210         complete
# 4       ESPORTSTMNT01_2690210         complete
# ...                       ...              ...
# 149227       9687-9687_game_5          partial
# 149228       9687-9687_game_5          partial
# 149229       9687-9687_game_5          partial
# 149230       9687-9687_game_5          partial
# 149231       9687-9687_game_5          partial
#
#                                                 url  league  year   split  \
# 0                                               NaN  LCK CL  2022  Spring
# 1                                               NaN  LCK CL  2022  Spring
# 2                                               NaN  LCK CL  2022  Spring
# 3                                               NaN  LCK CL  2022  Spring
# 4                                               NaN  LCK CL  2022  Spring
# ...                                             ...     ...   ...     ...
# 149227  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022     NaN
# 149228  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022     NaN
# 149229  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022     NaN
# 149230  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022     NaN
# 149231  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022     NaN
#
#         playoffs                 date  game  patch  ...  opp_csat15  \
# 0              0  2022-01-10 07:44:08     1  12.01  ...       121.0
# 1              0  2022-01-10 07:44:08     1  12.01  ...       100.0
# 2              0  2022-01-10 07:44:08     1  12.01  ...       119.0
# 3              0  2022-01-10 07:44:08     1  12.01  ...       149.0
# 4              0  2022-01-10 07:44:08     1  12.01  ...        21.0
# ...          ...                  ...   ...    ...  ...         ...
# 149227         0  2022-12-27 12:43:43     5  12.23  ...         NaN
# 149228         0  2022-12-27 12:43:43     5  12.23  ...         NaN
# 149229         0  2022-12-27 12:43:43     5  12.23  ...         NaN
# 149230         0  2022-12-27 12:43:43     5  12.23  ...         NaN
# 149231         0  2022-12-27 12:43:43     5  12.23  ...         NaN
#
#        golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 0             391.0      345.0       14.0       0.0         1.0        0.0
# 1             541.0     -275.0      -11.0       2.0         3.0        2.0
# 2            -475.0      153.0        1.0       0.0         3.0        0.0
# 3            -793.0    -1343.0      -34.0       2.0         1.0        2.0
# 4             443.0     -497.0        7.0       1.0         2.0        2.0
# ...             ...        ...        ...       ...         ...        ...
# 149227          NaN        NaN        NaN       NaN         NaN        NaN
# 149228          NaN        NaN        NaN       NaN         NaN        NaN
# 149229          NaN        NaN        NaN       NaN         NaN        NaN
# 149230          NaN        NaN        NaN       NaN         NaN        NaN
# 149231          NaN        NaN        NaN       NaN         NaN        NaN
#
#        opp_killsat15 opp_assistsat15 opp_deathsat15
# 0                0.0             1.0            0.0
# 1                0.0             5.0            1.0
# 2                3.0             3.0            2.0
# 3                3.0             3.0            0.0
# 4                0.0             6.0            2.0
# ...              ...             ...            ...
# 149227           NaN             NaN            NaN
# 149228           NaN             NaN            NaN
# 149229           NaN             NaN            NaN
# 149230           NaN             NaN            NaN
# 149231           NaN             NaN            NaN
#
# [149232 rows x 123 columns]

# %% [markdown]
# ### Framing the Problem

# %% [markdown]
# The League of Legends dataset loaded above give insight on games from the 2022 season. It specifies information and statistics for each player for each specific game, including bans, kills, deaths, damage taken per minute, wards placed, etc. As a beginner to the game, I wonder if there are aspects of the game that could be predicted, such as:
# 1. Which team will win or lose a game?
# 2. After the first 10 minutes have played out, which team will win or lose a game?
# 2. How long will this game take?
# 3. How much damage to champions will this team have?
# 4. How much damage will this team take?
#
# The specific question that I will be focusing on predicting will be "which team will win or lose a game?"

# %% [markdown]
# ### Cleaning

# %%
'''
Data Cleaning:
I manually filled in NaN values for certain columns to either 'unknown' or 'n/a', depending on if the 
information was missing intentionally or not. I dropped columns that were meant for individual statistics, since I am focusing on
team statistics. For the rest of the numerical values that weren't filled in, 
I calculated the median and filled in the NaN values accordingly. 
'''
league_cleaned = league.copy()
league_cleaned = league_cleaned[league_cleaned['position'] == 'team']
league_cleaned['result'] = league_cleaned['result'].astype(bool)
league_cleaned['playoffs'] = league_cleaned['playoffs'].astype(bool)
league_cleaned = league_cleaned.fillna({'url': 'unknown', 
                                        'split': 'unknown',
                                       })
columns = league_cleaned.columns
median_imputation = list(range(30,37)) + list(range(67, len(columns)))

for i in median_imputation:
    col = columns[i]
    league_cleaned[col] = league_cleaned[col].fillna(league_cleaned[col].median())
    

    
dropped = [columns[i] for i in range(40, 58)] + [columns[i] for i in range(60, 67)]
league_cleaned = league_cleaned.drop(columns=dropped)
league_cleaned = league_cleaned.drop(columns=['playername', 'playerid', 'champion'])

league_cleaned
# Out:
# /Users/andrewtan/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/andrewtan/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/andrewtan/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/andrewtan/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/andrewtan/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#                        gameid datacompleteness  \
# 10      ESPORTSTMNT01_2690210         complete
# 11      ESPORTSTMNT01_2690210         complete
# 22      ESPORTSTMNT01_2690219         complete
# 23      ESPORTSTMNT01_2690219         complete
# 34           8401-8401_game_1          partial
# ...                       ...              ...
# 149207       9687-9687_game_3          partial
# 149218       9687-9687_game_4          partial
# 149219       9687-9687_game_4          partial
# 149230       9687-9687_game_5          partial
# 149231       9687-9687_game_5          partial
#
#                                                 url  league  year    split  \
# 10                                          unknown  LCK CL  2022   Spring
# 11                                          unknown  LCK CL  2022   Spring
# 22                                          unknown  LCK CL  2022   Spring
# 23                                          unknown  LCK CL  2022   Spring
# 34      https://lpl.qq.com/es/stats.shtml?bmid=8401     LPL  2022   Spring
# ...                                             ...     ...   ...      ...
# 149207  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022  unknown
# 149218  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022  unknown
# 149219  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022  unknown
# 149230  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022  unknown
# 149231  https://lpl.qq.com/es/stats.shtml?bmid=9687      DC  2022  unknown
#
#         playoffs                 date  game  patch  ...  opp_csat15  \
# 10         False  2022-01-10 07:44:08     1  12.01  ...       510.0
# 11         False  2022-01-10 07:44:08     1  12.01  ...       487.0
# 22         False  2022-01-10 08:38:24     1  12.01  ...       555.0
# 23         False  2022-01-10 08:38:24     1  12.01  ...       533.0
# 34         False  2022-01-10 09:24:26     1  12.01  ...       505.0
# ...          ...                  ...   ...    ...  ...         ...
# 149207     False  2022-12-27 10:54:36     3  12.23  ...       505.0
# 149218     False  2022-12-27 11:45:06     4  12.23  ...       505.0
# 149219     False  2022-12-27 11:45:06     4  12.23  ...       505.0
# 149230     False  2022-12-27 12:43:43     5  12.23  ...       505.0
# 149231     False  2022-12-27 12:43:43     5  12.23  ...       505.0
#
#        golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 10            107.0    -1617.0      -23.0       5.0        10.0        6.0
# 11           -107.0     1617.0       23.0       6.0        18.0        5.0
# 22          -1763.0     -906.0      -22.0       1.0         1.0        3.0
# 23           1763.0      906.0       22.0       3.0         3.0        1.0
# 34              0.0        0.0        0.0       4.0         5.0        4.0
# ...             ...        ...        ...       ...         ...        ...
# 149207          0.0        0.0        0.0       4.0         5.0        4.0
# 149218          0.0        0.0        0.0       4.0         5.0        4.0
# 149219          0.0        0.0        0.0       4.0         5.0        4.0
# 149230          0.0        0.0        0.0       4.0         5.0        4.0
# 149231          0.0        0.0        0.0       4.0         5.0        4.0
#
#        opp_killsat15 opp_assistsat15 opp_deathsat15
# 10               6.0            18.0            5.0
# 11               5.0            10.0            6.0
# 22               3.0             3.0            1.0
# 23               1.0             1.0            3.0
# 34               4.0             5.0            4.0
# ...              ...             ...            ...
# 149207           4.0             5.0            4.0
# 149218           4.0             5.0            4.0
# 149219           4.0             5.0            4.0
# 149230           4.0             5.0            4.0
# 149231           4.0             5.0            4.0
#
# [24872 rows x 95 columns]

# %%
def getChampions(row):
    game, team = row['gameid'], row['teamname']
    player_stats = league[(league['gameid'] == game) & (league['teamname'] == team)]
    champions = player_stats['champion']
    print(champions)
    return champions

test = league_cleaned.apply(getChampions, axis=1)
test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       4     champions = player_stats['champion'].sum()
#       5     return champions
# ----> 7 test = league_cleaned.apply(getChampions, axis=1)
#       8 test
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/frame.py:8741, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8730 from pandas.core.apply import frame_apply
#    8732 op = frame_apply(
#    8733     self,
#    8734     func=func,
#    (...)
#    8739     kwargs=kwargs,
#    8740 )
# -> 8741 return op.apply()
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/apply.py:812, in FrameApply.apply_standard(self)
#     811 def apply_standard(self):
# --> 812     results, res_index = self.apply_series_generator()
#     814     # wrap results
#     815     return self.wrap_results(results, res_index)
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/apply.py:828, in FrameApply.apply_series_generator(self)
#     825 with option_context("mode.chained_assignment", None):
#     826     for i, v in enumerate(series_gen):
#     827         # ignore SettingWithCopy here in case the user mutates
# --> 828         results[i] = self.f(v)
#     829         if isinstance(results[i], ABCSeries):
#     830             # If we have a view on v, we need to make a copy because
#     831             #  series_generator will swap out the underlying data
#     832             results[i] = results[i].copy(deep=False)
#
# Cell In[21], line 4, in getChampions(row)
#       2 game, team = row['gameid'], row['teamname']
#       3 player_stats = league[(league['gameid'] == game) & (league['teamname'] == team)]
# ----> 4 champions = player_stats['champion'].sum()
#       5 return champions
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/generic.py:10708, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10688 @doc(
#   10689     _num_doc,
#   10690     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   10706     **kwargs,
#   10707 ):
# > 10708     return NDFrame.sum(
#   10709         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710     )
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/generic.py:10446, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10437 def sum(
#   10438     self,
#   10439     axis=None,
#    (...)
#   10444     **kwargs,
#   10445 ):
# > 10446     return self._min_count_stat_function(
#   10447         "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448     )
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/generic.py:10428, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10413     warnings.warn(
#   10414         "Using the level keyword in DataFrame and Series aggregations is "
#   10415         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10418         stacklevel=4,
#   10419     )
#   10420     return self._agg_by_level(
#   10421         name,
#   10422         axis=axis,
#    (...)
#   10426         numeric_only=numeric_only,
#   10427     )
# > 10428 return self._reduce(
#   10429     func,
#   10430     name=name,
#   10431     axis=axis,
#   10432     skipna=skipna,
#   10433     numeric_only=numeric_only,
#   10434     min_count=min_count,
#   10435 )
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/series.py:4392, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4388     raise NotImplementedError(
#    4389         f"Series.{name} does not implement numeric_only."
#    4390     )
#    4391 with np.errstate(all="ignore"):
# -> 4392     return op(delegate, skipna=skipna, **kwds)
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/pandas/core/nanops.py:590, in nansum(values, axis, skipna, min_count, mask)
#     585 elif is_timedelta64_dtype(dtype):
#     586     # error: Incompatible types in assignment (expression has type
#     587     # "Type[float64]", variable has type "dtype")
#     588     dtype_sum = np.float64  # type: ignore[assignment]
# --> 590 the_sum = values.sum(axis, dtype=dtype_sum)
#     591 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     593 return the_sum
#
# File ~/opt/anaconda3/envs/dsc80/lib/python3.8/site-packages/numpy/core/_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Baseline Model

# %%
X_train, X_test, y_train, y_test = train_test_split(league_cleaned[['killsat10', 'deathsat10', 'assistsat10']],
                                                   league_cleaned['result'],
                                                   test_size=0.25,
                                                   random_state=1)


dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train, y_train)
dt.score(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.5791251206175619

# %% [markdown]
# ### Final Model

# %%
# TODO

# %% [markdown]
# ### Fairness Analysis

# %%
# TODO
